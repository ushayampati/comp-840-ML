# %% [markdown]
# ## Titanic with feature engineering.

# %%
# Imports
# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
# %matplotlib inline

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Get titanic & test csv files as a DataFrame

# %%
X_train = pd.read_csv("./train.csv")
X_test_orig = pd.read_csv("./test.csv")

# %% [markdown]
# Build the training set

# %%
y_train = X_train.pop("Survived")

# %% [markdown]
# Combine train and test for feature engineering

# %%
data = X_train.append(X_test_orig, ignore_index=True)

# %%
data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %% [markdown]
# To Do: How many feature column? Hing: use info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# To Do: How many missing values. Hint: use isnull() and sum()

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# Find more useful information to learn: get the titles of each passenger

# %%
data['Title'] = data.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip())
data.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked Title
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S    Mr
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C   Mrs
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3  female  35.0      1      0            113803  53.1000  C123        S   Mrs
# 4    male  35.0      0      0            373450   8.0500   NaN        S    Mr

# %% [markdown]
# To Do: Count diferent values of a feature. Hint: use value_counts()

# %%
data['Title'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Major             2
# Mlle              2
# Ms                2
# the Countess      1
# Sir               1
# Dona              1
# Lady              1
# Mme               1
# Jonkheer          1
# Don               1
# Capt              1
# Name: Title, dtype: int64

# %% [markdown]
# Create bins for the title values

# %%
bin_titles = {
    "Capt":       "Officer",
    "Col":        "Officer",
    "Major":      "Officer",
    "Jonkheer":   "Royalty",
    "Don":        "Royalty",
    "Sir" :       "Royalty",
    "Dr":         "Officer",
    "Rev":        "Officer",
    "the Countess":"Royalty",
    "Dona":       "Royalty",
    "Mme":        "Mrs",
    "Mlle":       "Miss",
    "Ms":         "Mrs",
    "Mr" :        "Mr",
    "Mrs" :       "Mrs",
    "Miss" :      "Miss",
    "Master" :    "Master",
    "Lady" :      "Royalty"
}

# %% [markdown]
# map the titles to title bins

# %%
data.Title = data.Title.map(bin_titles)
data.Title.value_counts()
# Out:
# Mr         757
# Miss       262
# Mrs        200
# Master      61
# Officer     23
# Royalty      6
# Name: Title, dtype: int64

# %% [markdown]
# Filling Missing Values for Age feature

# %%
# group by Sex, Pclass, and Title
grouped = data.groupby(['Sex','Pclass', 'Title'])

# %% [markdown]
# view the median Age by the grouped features

# %%
grouped.Age.median()
# Out:
# Sex     Pclass  Title
# female  1       Miss       30.0
#                 Mrs        45.0
#                 Officer    49.0
#                 Royalty    39.0
#         2       Miss       20.0
#                 Mrs        30.0
#         3       Miss       18.0
#                 Mrs        31.0
# male    1       Master      6.0
#                 Mr         41.5
#                 Officer    52.0
#                 Royalty    40.0
#         2       Master      2.0
#                 Mr         30.0
#                 Officer    41.5
#         3       Master      6.0
#                 Mr         26.0
# Name: Age, dtype: float64

# %%
data.Age = grouped.Age.apply(lambda x: x.fillna(x.median()))

# %% [markdown]
# Fill Embarked with the most frequent value

# %%
most_embarked = data.Embarked.value_counts().index[0]
data["Embarked"].fillna(most_embarked, inplace=True)

# %% [markdown]
# Fill Fare with the mean value of all fare

# %%
data["Fare"].fillna(data.Fare.mean(), inplace=True)

# %% [markdown]
# To Do: Check null value again (and the Cabin feature will be dropped)

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# Title             0
# dtype: int64

# %% [markdown]
# Apply 1-hot encoding for categorical feature Sex

# %%
data = pd.get_dummies(data, columns=['Sex'], prefix = ['Sex'])
data = pd.get_dummies(data, columns=['Embarked'], prefix = ['Embarked'])
data = pd.get_dummies(data, columns=['Title'], prefix = ['Title'])

# %% [markdown]
# To Do: apply 1-hot encoding for the other categorical features

# %%
data
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# 5               6       3                                   Moran, Mr. James
# 6               7       1                            McCarthy, Mr. Timothy J
# 7               8       3                     Palsson, Master. Gosta Leonard
# 8               9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9              10       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10             11       3                    Sandstrom, Miss. Marguerite Rut
# 11             12       1                           Bonnell, Miss. Elizabeth
# 12             13       3                     Saundercock, Mr. William Henry
# 13             14       3                        Andersson, Mr. Anders Johan
# 14             15       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15             16       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16             17       3                               Rice, Master. Eugene
# 17             18       2                       Williams, Mr. Charles Eugene
# 18             19       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19             20       3                            Masselmani, Mrs. Fatima
# 20             21       2                               Fynney, Mr. Joseph J
# 21             22       2                              Beesley, Mr. Lawrence
# 22             23       3                        McGowan, Miss. Anna "Annie"
# 23             24       1                       Sloper, Mr. William Thompson
# 24             25       3                      Palsson, Miss. Torborg Danira
# 25             26       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26             27       3                            Emir, Mr. Farred Chehab
# 27             28       1                     Fortune, Mr. Charles Alexander
# 28             29       3                      O'Dwyer, Miss. Ellen "Nellie"
# 29             30       3                                Todoroff, Mr. Lalio
# ...           ...     ...                                                ...
# 1279         1280       3                               Canavan, Mr. Patrick
# 1280         1281       3                        Palsson, Master. Paul Folke
# 1281         1282       1                         Payne, Mr. Vivian Ponsonby
# 1282         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 1283         1284       3                      Abbott, Master. Eugene Joseph
# 1284         1285       2                               Gilbert, Mr. William
# 1285         1286       3                           Kink-Heilmann, Mr. Anton
# 1286         1287       1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 1287         1288       3                               Colbert, Mr. Patrick
# 1288         1289       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 1289         1290       3                     Larsson-Rondberg, Mr. Edvard A
# 1290         1291       3                           Conlon, Mr. Thomas Henry
# 1291         1292       1                            Bonnell, Miss. Caroline
# 1292         1293       2                                    Gale, Mr. Harry
# 1293         1294       1                     Gibson, Miss. Dorothy Winifred
# 1294         1295       1                             Carrau, Mr. Jose Pedro
# 1295         1296       1                       Frauenthal, Mr. Isaac Gerald
# 1296         1297       2       Nourney, Mr. Alfred (Baron von Drachstedt")"
# 1297         1298       2                          Ware, Mr. William Jeffery
# 1298         1299       1                         Widener, Mr. George Dunton
# 1299         1300       3                    Riordan, Miss. Johanna Hannah""
# 1300         1301       3                          Peacock, Miss. Treasteall
# 1301         1302       3                             Naughton, Miss. Hannah
# 1302         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303         1304       3                     Henriksson, Miss. Jenny Lovisa
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#        Age  SibSp  Parch              Ticket      Fare        Cabin  \
# 0     22.0      1      0           A/5 21171    7.2500          NaN
# 1     38.0      1      0            PC 17599   71.2833          C85
# 2     26.0      0      0    STON/O2. 3101282    7.9250          NaN
# 3     35.0      1      0              113803   53.1000         C123
# 4     35.0      0      0              373450    8.0500          NaN
# 5     26.0      0      0              330877    8.4583          NaN
# 6     54.0      0      0               17463   51.8625          E46
# 7      2.0      3      1              349909   21.0750          NaN
# 8     27.0      0      2              347742   11.1333          NaN
# 9     14.0      1      0              237736   30.0708          NaN
# 10     4.0      1      1             PP 9549   16.7000           G6
# 11    58.0      0      0              113783   26.5500         C103
# 12    20.0      0      0           A/5. 2151    8.0500          NaN
# 13    39.0      1      5              347082   31.2750          NaN
# 14    14.0      0      0              350406    7.8542          NaN
# 15    55.0      0      0              248706   16.0000          NaN
# 16     2.0      4      1              382652   29.1250          NaN
# 17    30.0      0      0              244373   13.0000          NaN
# 18    31.0      1      0              345763   18.0000          NaN
# 19    31.0      0      0                2649    7.2250          NaN
# 20    35.0      0      0              239865   26.0000          NaN
# 21    34.0      0      0              248698   13.0000          D56
# 22    15.0      0      0              330923    8.0292          NaN
# 23    28.0      0      0              113788   35.5000           A6
# 24     8.0      3      1              349909   21.0750          NaN
# 25    38.0      1      5              347077   31.3875          NaN
# 26    26.0      0      0                2631    7.2250          NaN
# 27    19.0      3      2               19950  263.0000  C23 C25 C27
# 28    18.0      0      0              330959    7.8792          NaN
# 29    26.0      0      0              349216    7.8958          NaN
# ...    ...    ...    ...                 ...       ...          ...
# 1279  21.0      0      0              364858    7.7500          NaN
# 1280   6.0      3      1              349909   21.0750          NaN
# 1281  23.0      0      0               12749   93.5000          B24
# 1282  51.0      0      1            PC 17592   39.4000          D28
# 1283  13.0      0      2           C.A. 2673   20.2500          NaN
# 1284  47.0      0      0          C.A. 30769   10.5000          NaN
# 1285  29.0      3      1              315153   22.0250          NaN
# 1286  18.0      1      0               13695   60.0000          C31
# 1287  24.0      0      0              371109    7.2500          NaN
# 1288  48.0      1      1               13567   79.2000          B41
# 1289  22.0      0      0              347065    7.7750          NaN
# 1290  31.0      0      0               21332    7.7333          NaN
# 1291  30.0      0      0               36928  164.8667           C7
# 1292  38.0      1      0               28664   21.0000          NaN
# 1293  22.0      0      1              112378   59.4000          NaN
# 1294  17.0      0      0              113059   47.1000          NaN
# 1295  43.0      1      0               17765   27.7208          D40
# 1296  20.0      0      0       SC/PARIS 2166   13.8625          D38
# 1297  23.0      1      0               28666   10.5000          NaN
# 1298  50.0      1      1              113503  211.5000          C80
# 1299  18.0      0      0              334915    7.7208          NaN
# 1300   3.0      1      1  SOTON/O.Q. 3101315   13.7750          NaN
# 10             1         0          0              0              0
# 11             1         0          0              0              0
# 12             0         1          0              0              0
# 13             0         1          0              0              0
# 14             1         0          0              0              0
# 15             0         0          1              0              0
# 16             0         0          0              0              0
# 17             0         1          0              0              0
# 18             0         0          1              0              0
# 19             0         0          1              0              0
# 20             0         1          0              0              0
# 21             0         1          0              0              0
# 22             1         0          0              0              0
# 23             0         1          0              0              0
# 24             1         0          0              0              0
# 25             0         0          1              0              0
# 26             0         1          0              0              0
# 27             0         1          0              0              0
# 28             1         0          0              0              0
# 29             0         1          0              0              0
# ...          ...       ...        ...            ...            ...
# 1279           0         1          0              0              0
# 1280           0         0          0              0              0
# 1281           0         1          0              0              0
# 1282           0         0          1              0              0
# 1283           0         0          0              0              0
# 1284           0         1          0              0              0
# 1285           0         1          0              0              0
# 1286           0         0          1              0              0
# 1287           0         1          0              0              0
# 1288           0         0          1              0              0
# 1289           0         1          0              0              0
# 1290           0         1          0              0              0
# 1291           1         0          0              0              0
# 1292           0         1          0              0              0
# 1293           1         0          0              0              0
# 1294           0         1          0              0              0
# 1295           0         1          0              0              0
# 1296           0         1          0              0              0
# 1297           0         1          0              0              0
# 1298           0         1          0              0              0
# 1299           1         0          0              0              0
# 1300           1         0          0              0              0
# 1301           1         0          0              0              0
# 1302           0         0          1              0              0
# 1303           1         0          0              0              0
# 1304           0         1          0              0              0
# 1305           0         0          0              0              1
# 1306           0         1          0              0              0
# 1307           0         1          0              0              0
# 1308           0         0          0              0              0
#
# [1309 rows x 20 columns]

# %% [markdown]
# Add new synthetic feature of Family Size

# %%
data['Family_Size'] = data['Parch'] + data['SibSp'] + 1

# %% [markdown]
# Add new has_cabin feature (yes or no)

# %%
data['Has_Cabin'] = ~data.Cabin.isnull()

# %% [markdown]
# Binning numerical columns

# %%
data['CatAge'] = pd.qcut(data.Age, q=4, labels=False )

# %% [markdown]
# Drop un-used features

# %%
data = data.drop(['Parch','SibSp','PassengerId','Name','Ticket','Cabin', 'Age'], axis=1)

# %%
data
# Out:
#       Pclass      Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  \
# 0          3    7.2500           0         1           0           0
# 1          1   71.2833           1         0           1           0
# 2          3    7.9250           1         0           0           0
# 3          1   53.1000           1         0           0           0
# 4          3    8.0500           0         1           0           0
# 5          3    8.4583           0         1           0           1
# 6          1   51.8625           0         1           0           0
# 7          3   21.0750           0         1           0           0
# 8          3   11.1333           1         0           0           0
# 9          2   30.0708           1         0           1           0
# 10         3   16.7000           1         0           0           0
# 11         1   26.5500           1         0           0           0
# 12         3    8.0500           0         1           0           0
# 13         3   31.2750           0         1           0           0
# 14         3    7.8542           1         0           0           0
# 15         2   16.0000           1         0           0           0
# 16         3   29.1250           0         1           0           1
# 17         2   13.0000           0         1           0           0
# 18         3   18.0000           1         0           0           0
# 19         3    7.2250           1         0           1           0
# 20         2   26.0000           0         1           0           0
# 21         2   13.0000           0         1           0           0
# 1291           1             0           1         0          0
# 1292           1             0           0         1          0
# 1293           0             0           1         0          0
# 1294           1             0           0         1          0
# 1295           0             0           0         1          0
# 1296           0             0           0         1          0
# 1297           1             0           0         1          0
# 1298           0             0           0         1          0
# 1299           0             0           1         0          0
# 1300           1             0           1         0          0
# 1301           0             0           1         0          0
# 1302           0             0           0         0          1
# 1303           1             0           1         0          0
# 1304           1             0           0         1          0
# 1305           0             0           0         0          0
# 1306           1             0           0         1          0
# 1307           1             0           0         1          0
# 1308           0             1           0         0          0
#
#       Title_Officer  Title_Royalty  Family_Size  Has_Cabin  CatAge
# 0                 0              0            2      False       1
# 1                 0              0            2       True       3
# 2                 0              0            1      False       1
# 3                 0              0            2       True       2
# 4                 0              0            1      False       2
# 5                 0              0            1      False       1
# 6                 0              0            1       True       3
# 7                 0              0            5      False       0
# 8                 0              0            3      False       2
# 9                 0              0            2      False       0
# 10                0              0            3       True       0
# 11                0              0            1       True       3
# 12                0              0            1      False       0
# 13                0              0            7      False       3
# 14                0              0            1      False       0
# 15                0              0            1      False       3
# 16                0              0            6      False       0
# 17                0              0            1      False       2
# 18                0              0            2      False       2
# 19                0              0            1      False       2
# 20                0              0            1      False       2
# 21                0              0            1       True       2
# 22                0              0            1      False       0
# 23                0              0            1       True       2
# 24                0              0            5      False       0
# 25                0              0            7      False       3
# 26                0              0            1      False       1
# 27                0              0            6       True       0
# 28                0              0            1      False       0
# 29                0              0            1      False       1
# ...             ...            ...          ...        ...     ...
# 1279              0              0            1      False       0
# 1280              0              0            5      False       0
# 1281              0              0            1       True       1
# 1282              0              0            2       True       3
# 1283              0              0            3      False       0
# 1284              0              0            1      False       3
# 1285              0              0            5      False       2
# 1286              0              0            2       True       0
# 1287              0              0            1      False       1
# 1288              0              0            3       True       3
# 1289              0              0            1      False       1
# 1290              0              0            1      False       2
# 1291              0              0            1       True       2
# 1292              0              0            2      False       3
# 1293              0              0            2      False       1
# 1294              0              0            1      False       0
# 1295              0              0            2       True       3
# 1296              0              0            1       True       0
# 1297              0              0            2      False       1
# 1298              0              0            3       True       3
# 1299              0              0            1      False       0
# 1300              0              0            3      False       0
# 1301              0              0            1      False       0
# 1302              0              0            2       True       3
# 1303              0              0            1      False       2
# 1304              0              0            1      False       1
# 1305              0              1            1       True       3
# 1306              0              0            1      False       3
# 1307              0              0            1      False       1
# 1308              0              0            3      False       0
#
# [1309 rows x 16 columns]

# %% [markdown]
# Rebuild the training set and test set

# %%
X_train = data.iloc[:891]
X_test = data.iloc[891:]

# %% [markdown]
# ## Build Classification Model
#
# ### Use a simple Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# split out our own test dataset from the training set.

# %%
X_train_small = data.iloc[:800]
X_test_small = data.iloc[800:891]
y_train_small = y_train.iloc[:800]
y_test_small = y_train.iloc[800:891]

# %%
dt1 = DecisionTreeClassifier(random_state=42)
dt1.fit(X_train_small, y_train_small)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
cross_val_score(dt1, X_train_small, y_train_small, cv=3, scoring="accuracy")
# Out:
# array([0.7752809 , 0.78277154, 0.80827068])

# %%
from sklearn.metrics import roc_curve, auc
y_pred_small = dt1.predict(X_test_small)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_small, y_pred_small)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.7974716202270382

# %% [markdown]
# Fine tune hyper-parameters with GridSearchCV

# %%
dt_params = [
   { 'max_depth': [1, 2, 4, 8, 16, 32, 64], 
     'min_samples_leaf' : [1, 2, 3, 4, 5, 6],
   },
]

# %%
dt_cv = GridSearchCV(estimator=dt1, param_grid=dt_params, cv=4)
dt_cv.fit(X_train_small, y_train_small)
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=42,
#                                               splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_depth': [1, 2, 4, 8, 16, 32, 64],
#                           'min_samples_leaf': [1, 2, 3, 4, 5, 6]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
cross_val_score(dt_cv.best_estimator_, X_train_small, y_train_small, cv=3, scoring="accuracy")
# Out:
# array([0.7752809 , 0.82771536, 0.79699248])

# %%
print("Optimal params: {}".format(dt_cv.best_estimator_))
# Out:
# Optimal params: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=16,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
from sklearn.metrics import roc_curve, auc
y_pred_small = dt_cv.best_estimator_.predict(X_test_small)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_small, y_pred_small)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.7915376676986585

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler() #center the distribution around zero (mean), with a standard deviation of 1.
sc.fit(X_train_small)
X_train_small_sc = sc.transform(X_train_small)
X_test_small_sc = sc.transform(X_test_small)

# %%
from sklearn.tree import DecisionTreeClassifier
dt2 = DecisionTreeClassifier(random_state=42)
dt2.fit(X_test_small_sc, y_test_small)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
from sklearn.metrics import roc_curve, auc
y_pred_small = dt2.predict(X_test_small_sc)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_small, y_pred_small)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 1.0

# %% [markdown]
# To Do: Experiment with scaled data. Scale the test data and use decision tree classifier to see if the results in terms of AUC improve.

# %%
dt_params = [
   { 'max_depth': [1, 2, 4, 8, 16, 32, 64], 
     'min_samples_leaf' : [1, 2, 3, 4, 5, 6],
   },
]

# %%
dt3_cv = GridSearchCV(estimator=dt2, param_grid=dt_params, cv=4)
dt3_cv.fit(X_test_small_sc, y_test_small)
# Out:
# C:\Users\usha\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=4, error_score='raise-deprecating',
#              estimator=DecisionTreeClassifier(class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort=False, random_state=42,
#                                               splitter='best'),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_depth': [1, 2, 4, 8, 16, 32, 64],
#                           'min_samples_leaf': [1, 2, 3, 4, 5, 6]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print("Optimal params: {}".format(dt3_cv.best_estimator_))
# Out:
# Optimal params: DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=42, splitter='best')

# %%
from sklearn.metrics import roc_curve, auc
y_pred_small = dt3_cv.best_estimator_.predict(X_test_small)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_small, y_pred_small)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.5

# %% [markdown]
# To Do: Continue with the last exercise and use GridSearchCV to find the best parameter for the desicision tree classifier

# %% [markdown]
# ### Use a random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rnd_clf = RandomForestClassifier(random_state=42, n_estimators=100)
rnd_clf.fit(X_train_small, y_train_small)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred_small = rnd_clf.predict(X_test_small)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_small, y_pred_small)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.8237874097007224

# %% [markdown]
# Prepare prediction results for submission to Kaggle

# %%
y_pred = rnd_clf.predict(X_test)

submission = pd.DataFrame({
        "PassengerId": X_test_orig["PassengerId"],
        "Survived": y_pred
    })
submission.to_csv('titanic.csv', index=False)
